# %%
import calc_functions
calc_functions.sum(2,4)
# Out:
# 2

# %%
import calc_functions
calc_functions.difference(4,2)
# Out:
# 2

# %%
import calc_functions
calc_functions.product(4,2)
# Out:
# 8

# %%
import calc_functions
calc_functions.division(4,2)
# Out:
# 2.0

# %%
import calc_functions
calc_functions.prime(8)
# Out:
# Not Prime Number

# %%
import calc_functions
calc_functions.factorial(5)
# Out:
# 120
